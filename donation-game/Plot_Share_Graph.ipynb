# %%
"""
BROKE_PUNISHMENT = 0
SAVING_BONUS = 0.1
BONUS_PERIOD = 20

REWARD_FUNC = get_reward_func(REWARD_PAIR, BROKE_PUNISHMENT, SAVING_BONUS, BONUS_PERIOD)
PLAYER_SALARY_OPTIONS = [5, 10, 15] 
ROBOT_SALARY_OPTIONS = [0]
PAY_PERIOD_OPTIONS = [6, 8, 10]
HORIZON = 100
EXPENSE_OPTIONS = [1, 1, 1, 1, 2]
DONATION_OPTIONS = [1]

Altruistic:
'give_count': 72, 'keep_count': 28

Latino:
'give_count': 55, 'keep_count': 45,

White:
'give_count': 45, 'keep_count': 55

Selfish:
'give_count': 36, 'keep_count': 64
"""

# %%
labels = ["Fully altruistic", "Latino", "White", "Non-altruistic"]
give_stats = [72, 55, 45, 36]

# %%
import matplotlib.pyplot as plt

# Data and labels
labels = ["Fully altruistic", "Latino", "White", "Non-altruistic"]
give_stats = [0.72, 0.55, 0.45, 0.36]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(labels, give_stats, width=0.4)

# Add titles and labels
plt.xlabel('IRL learned rewards')
plt.ylabel('Sharing percentage')

plt.ylim(0, 1) 

# Add value labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2 - 0.05, yval + 0.005, yval)

# Show the chart
plt.show()

# %%
# Sample data
x = [i for i in range(0, 100)]
# selfish
y1 = [0, 0, 0, 0, 0, 1, 2, 3, 3, 4, 4, 4, 5, 6, 7, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 11, 12, 12, 12, 13, 13, 13, 13, 13, 13, 13, 14, 15, 15, 15, 15, 15, 15, 15, 15, 16, 17, 18, 18, 19, 19, 19, 19, 19, 20, 21, 22, 22, 22, 22, 22, 22, 23, 23, 24, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 26, 27, 28, 29, 29, 29, 29, 29, 29, 29, 29, 30, 30, 31]
#y1 = [13,11,10,9,8,6,5,3,17,14,12,10,7,5,3,1,0,0,15,13,11,10,8,6,4,3,2,1,15,13,11,10,9,7,6,5,4,3,17,14,12,10,9,8,6,4,3,2,15,14,12,10,9,7,6,5,4,2,16,15,14,13,12,10,7,5,4,2,16,13,11,9,7,5,3,1,0,0,15,14,12,10,9,7,5,4,3,1,15,14,12,11,9,8,7,5,3,1,15,13]
# white
y2 = [0, 0, 0, 0, 0, 0, 0, 0, 1, 2, 3, 4, 4, 4, 5, 6, 7, 7, 7, 7, 8, 8, 8, 8, 9, 10, 10, 10, 10, 10, 10, 11, 11, 11, 12, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 14, 15, 15, 16, 16, 16, 16, 16, 16, 17, 18, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 20, 21, 22, 22, 22, 23, 23, 23, 24, 25, 26, 26, 27, 27, 27, 27, 27, 27, 27, 28, 29, 29, 29, 30, 30, 30, 30, 31, 32, 32, 32, 32, 32]
#y2 = [14,13,12,11,10,9,7,5,18,16,14,11,9,8,6,4,1,0,15,14,12,11,10,8,6,3,1,0,15,13,12,10,9,8,5,3,1,0,15,14,13,12,11,9,7,6,4,2,16,14,13,12,10,9,8,6,4,2,15,14,12,11,10,9,8,7,6,4,17,14,13,12,10,9,8,6,4,2,16,14,13,12,10,9,7,6,4,1,15,14,12,11,10,8,6,3,2,1,15,13]
# latino
y3 = [0, 1, 2, 3, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 11, 11, 11, 11, 12, 13, 14, 15, 16, 17, 17, 17, 17, 17, 18, 19, 20, 21, 22, 23, 23, 23, 23, 23, 24, 25, 26, 27, 28, 29, 29, 29, 29, 29, 30, 31, 32, 33, 34, 35, 35, 35, 35, 35, 36, 37, 38, 38, 39, 40, 41, 41, 41, 41, 42, 42, 43, 44, 45, 46, 47, 47, 47, 47, 48, 49, 50, 51, 52, 53, 54, 54, 54, 54, 55, 56, 57, 58, 59, 60, 60, 60, 60, 60]
#y3 = [14,12,9,7,5,2,0,0,15,13,11,9,7,5,2,0,0,0,15,13,11,8,6,4,2,0,0,0,15,14,12,9,7,5,3,1,0,0,15,14,11,9,7,5,3,1,0,0,15,14,12,10,8,5,3,1,0,0,15,14,12,10,8,7,5,3,1,0,15,14,12,11,9,7,5,3,1,0,15,14,12,10,8,6,4,2,0,0,15,14,12,9,7,5,3,1,0,0,15,14]
# altruistic
y4 = [1, 2, 3, 4, 5, 6, 6, 6, 6, 7, 8, 9, 10, 11, 12, 13, 13, 13, 13, 14, 15, 15, 16, 17, 18, 19, 19, 19, 19, 20, 21, 22, 23, 24, 25, 25, 25, 25, 25, 26, 27, 28, 29, 30, 30, 31, 31, 31, 31, 32, 33, 34, 35, 36, 37, 37, 37, 37, 37, 38, 39, 40, 40, 41, 42, 42, 42, 42, 42, 43, 44, 45, 46, 47, 48, 49, 49, 49, 49, 50, 51, 52, 52, 53, 54, 55, 55, 55, 55, 56, 57, 58, 59, 60, 61, 62, 62, 62, 62, 63]
#y4 = [13,11,8,6,3,1,0,0,15,13,11,9,7,4,2,0,0,0,15,13,11,10,8,5,3,1,0,0,15,12,10,8,5,3,1,0,0,0,15,13,11,8,6,4,3,1,0,0,15,12,9,7,5,3,1,0,0,0,15,12,10,7,6,4,1,0,0,0,15,13,11,9,6,4,2,0,0,0,15,12,10,8,7,5,3,1,0,0,15,13,11,9,7,5,3,1,0,0,15,13]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each line
plt.plot(x, y1, label='Selfish')
plt.plot(x, y2, label='White')
plt.plot(x, y3, label='Latino')
plt.plot(x, y4, label='Altruistic')

# Add a title and labels
plt.xlabel('Timestep')
plt.ylabel('Amount given')

# Add a legend
plt.legend()

# Show the plot
plt.show()
